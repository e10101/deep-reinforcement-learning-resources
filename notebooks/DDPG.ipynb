# %% [markdown]
# # DDPG

# %%
from tf_agents.agents.ddpg import ddpg_agent
from tf_agents.agents.dqn import dqn_agent
from tf_agents.environments import suite_gym, tf_py_environment
from tf_agents.networks import sequential, q_network, nest_map
from tf_agents.specs import tensor_spec
from tf_agents.utils import common
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import reverb_replay_buffer
from tf_agents.replay_buffers import reverb_utils
from tf_agents.drivers import py_driver
from tf_agents.policies import py_tf_eager_policy
from tf_agents.metrics import tf_metrics
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.drivers import dynamic_step_driver
from tf_agents.eval import metric_utils
from tf_agents.keras_layers import inner_reshape

import matplotlib
import matplotlib.pyplot as plt

import reverb

import tensorflow as tf
import pyvirtualdisplay
import functools


import PIL
from PIL import ImageDraw, ImageFont
import numpy as np
import IPython
import imageio
import base64

import os
import time

from absl import logging

# %%
logging.set_verbosity(logging.INFO)

# %%
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %%
env_name = 'Pendulum-v1'
train_or_retrain = True
num_iterations = 100_000

actor_fc_layers = (400, 300)
critic_obs_fc_layers = (400,)
critic_action_fc_layers=None
critic_joint_fc_layers=(300,)

learning_rate = 1e-4
num_eval_episodes = 10
replay_buffer_max_length = 100000
initial_collect_steps = 100
batch_size = 64
collect_steps_per_iteration = 1

log_interval = 200
eval_interval = 1000
video_recording_interval = 1_000

root_dir = os.path.join('./data', env_name)
summaries_flush_secs = 10

fc_layer_params = (100, 50)
gamma = 0.99
reward_scale_factor = 1.0
gradient_clipping = None
debug_summaries = False
summarize_grads_and_vars = False

# Params for train
use_tf_functions = True
train_steps_per_iteration = 1
actor_learning_rate=1e-4
critic_learning_rate=1e-3
dqda_clipping=None
td_errors_loss_fn = tf.compat.v1.losses.huber_loss

# Params for collect
epsilon_greedy = 0.1
replay_buffer_capacity = 100_000
ou_stddev=0.2
ou_damping=0.15

# Params for target update
target_update_tau = 0.05
target_update_period = 5

# Params for summaries and logging
summary_interval = 1_000
eval_metrics_callback = None

train_sequence_length = 1

# Params for checkpoints
train_checkpoint_interval = 10_000
policy_checkpoint_interval = 5_000
rb_checkpoint_interval = 20_000

# %% [markdown]
# ## Setup

# %%
root_dir = os.path.expanduser(root_dir)
train_dir = os.path.join(root_dir, 'train')
eval_dir = os.path.join(root_dir, 'eval')
video_dir = os.path.join(root_dir, 'video')

# Create the video recording directory
if not os.path.exists(video_dir):
    os.makedirs(video_dir)

# %%
# Train Summary Writer
train_summary_writer = tf.summary.create_file_writer(
    train_dir, flush_millis=summaries_flush_secs * 1000)
train_summary_writer.set_as_default()

# %%
# Eval Summary Writer
eval_summary_writer = tf.summary.create_file_writer(
    eval_dir, flush_millis=summaries_flush_secs * 1000)
eval_metrics = [
    tf_metrics.AverageReturnMetric(buffer_size=num_eval_episodes),
    tf_metrics.AverageEpisodeLengthMetric(buffer_size=num_eval_episodes)
]

# %%
# Create global_step
global_step = tf.compat.v1.train.get_or_create_global_step()

# %% [markdown]
# ### Video

# %%
def get_timestamp():
    import datetime
    return datetime.datetime.now().timestamp()

# %%
def embed_mp4(filename):
    video = open(filename, 'rb').read()
    b64 = base64.b64encode(video)
    
    tag = '''
    <video width="640" height="480" controls>
        <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())
    
    return IPython.display.HTML(tag)

# %%
def enhance_frame(frame: np.ndarray, text=None) -> np.ndarray:
    if text is None:
        return frame
    
    # Convert array to PIl.Image
    image = PIL.Image.fromarray(frame).convert('RGB')

    # Get draw context
    draw = ImageDraw.Draw(image, 'RGB')

    # Get font
    font = ImageFont.truetype('/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', 20)

    # Draw text
    draw.text((30, 30), text, font=font, fill=(0, 0, 0), stroke_width=1, stroke_fill=(255, 255, 255))

    return np.array(image)

# %%
def create_policy_eval_video(policy, eval_env, eval_py_env, filename=None, 
        num_episodes=3, fps=30, env_name=env_name, freeze_seconds=0,
        step=None):
    if filename is None:
        filename = str(get_timestamp())
        
    filename = filename + '.mp4'
    logging.info('Env: %s', env_name)
    logging.info('Filename: %s', filename)
    
    with imageio.get_writer(filename, fps=fps) as video:
        for idx in range(num_episodes):
            logging.info('Begin #%d of %d', idx+1, num_episodes)
            time_step = eval_env.reset()
            frame_idx = 0
            total_reward = 0.0
            
            total_reward += +time_step.reward.numpy()[0]
            
            text = f'Env: {env_name}'
            if step is not None:
                text += f'\nStp: {step}'
            text += f'\nEp:  {idx+1}/{num_episodes}\nFrm: {frame_idx}'
            text += f'\nRw:  {total_reward:.2f}'
            
            frame = enhance_frame(eval_py_env.render(mode='rgb_array'), text)
            video.append_data(frame)

            while not time_step.is_last():
                action_step = policy.action(time_step)
                time_step = eval_env.step(action_step.action)
                frame_idx += 1
                total_reward += +time_step.reward.numpy()[0]
                
                text = f'Env: {env_name}'
                if step is not None:
                    text += f'\nStp: {step}'
                text += f'\nEp:  {idx+1}/{num_episodes}\nFrm: {frame_idx}'
                text += f'\nRw:  {total_reward:.2f}'

                frame = enhance_frame(eval_py_env.render(mode='rgb_array'), text)
                video.append_data(frame)
                
                # Freeze frame for a few seconds
                if time_step.is_last() and freeze_seconds > 0:
                    for _ in range(fps * freeze_seconds):
                        video.append_data(frame)
    
    logging.info('All done')
    return filename
    # return embed_mp4(filename)

# %% [markdown]
# ### Train

# %%
dense = functools.partial(
    tf.keras.layers.Dense,
    activation=tf.keras.activations.relu,
    kernel_initializer=tf.compat.v1.variance_scaling_initializer(
        scale=1.0/3.0, mode='fan_in', distribution='uniform'
    )
)

# %%
# Create an actor network
def create_actor_network(fc_layer_units, action_spec):
    """Create an actor network for DDPG."""
    flat_action_spec = tf.nest.flatten(action_spec)
    if len(flat_action_spec) > 1:
        raise ValueError('Only a single action tensor is supported by this network.')
    flat_action_spec = flat_action_spec[0]

    fc_layers = [dense(num_units) for num_units in fc_layer_units]

    num_actions = flat_action_spec.shape.num_elements()
    action_fc_layer = tf.keras.layers.Dense(
        num_actions,
        activation=tf.keras.activations.tanh,
        kernel_initializer=tf.keras.initializers.RandomUniform(
            minval=-0.003, maxval=0.003
        )
    )

    scaling_layer = tf.keras.layers.Lambda(
        lambda x: common.scale_to_spec(x, flat_action_spec)
    )

    return sequential.Sequential(fc_layers + [action_fc_layer, scaling_layer])

# %%
def create_identity_layer():
    return tf.keras.layers.Lambda(lambda x: x)

def create_fc_network(layer_units):
    return sequential.Sequential([dense(num_units) for num_units in layer_units])

# %%
def create_critic_network(obs_fc_layer_units,
                          action_fc_layer_units,
                          joint_fc_layer_units):
    """Create a critic network for DDPG."""
    
    def split_inputs(inputs):
        return {'observation': inputs[0], 'action': inputs[1]}
    
    # Obs network
    obs_network = create_fc_network(
        obs_fc_layer_units) if obs_fc_layer_units else create_identity_layer()
    
    # Action network
    action_network = create_fc_network(
        action_fc_layer_units) if action_fc_layer_units else create_identity_layer()
    
    # Joint network
    joint_network = create_fc_network(
        joint_fc_layer_units) if joint_fc_layer_units else create_identity_layer()
    
    # Value layer
    value_fc_layer = tf.keras.layers.Dense(
        1,
        activation=None,
        kernel_initializer=tf.keras.initializers.RandomUniform(
            minval=-0.003, maxval=0.003))
    
    return sequential.Sequential([
        tf.keras.layers.Lambda(split_inputs),
        nest_map.NestMap({
            'observation': obs_network,
            'action': action_network
        }),
        nest_map.NestFlatten(),
        tf.keras.layers.Concatenate(),
        joint_network,
        value_fc_layer,
        inner_reshape.InnerReshape([1], [])
    ])

# %%
with tf.summary.record_if(lambda: tf.math.equal(global_step % summary_interval, 0)):
    # Create env
    tf_env = tf_py_environment.TFPyEnvironment(suite_gym.load(env_name))
    eval_py_env = suite_gym.load(env_name)
    eval_tf_env = tf_py_environment.TFPyEnvironment(eval_py_env)
    
    # Create Actor Net
    actor_net = create_actor_network(actor_fc_layers, tf_env.action_spec())

    # Create Critic Net
    critic_net = create_critic_network(critic_obs_fc_layers,
                                       critic_action_fc_layers,
                                       critic_joint_fc_layers)
    
    # Create Agent
    tf_agent = ddpg_agent.DdpgAgent(
        tf_env.time_step_spec(),
        tf_env.action_spec(),
        actor_network=actor_net,
        critic_network=critic_net,
        actor_optimizer=tf.compat.v1.train.AdamOptimizer(
            learning_rate=actor_learning_rate),
        critic_optimizer=tf.compat.v1.train.AdamOptimizer(
            learning_rate=critic_learning_rate),
        ou_stddev=ou_stddev,
        ou_damping=ou_damping,
        target_update_tau=target_update_tau,
        target_update_period=target_update_period,
        dqda_clipping=dqda_clipping,
        td_errors_loss_fn=td_errors_loss_fn,
        gamma=gamma,
        reward_scale_factor=reward_scale_factor,
        gradient_clipping=gradient_clipping,
        debug_summaries=debug_summaries,
        summarize_grads_and_vars=summarize_grads_and_vars,
        train_step_counter=global_step)
    tf_agent.initialize()
    
    
    # Train Metrics
    train_metrics = [
        tf_metrics.NumberOfEpisodes(),
        tf_metrics.EnvironmentSteps(),
        tf_metrics.AverageReturnMetric(),
        tf_metrics.AverageEpisodeLengthMetric(),
    ]
    
    # Policies
    eval_policy = tf_agent.policy
    collect_policy = tf_agent.collect_policy
    
    # Replay Buffer
    replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
        data_spec=tf_agent.collect_data_spec,
        batch_size=tf_env.batch_size,
        max_length=replay_buffer_capacity)
    
    # Initial Collect Driver
    initial_collect_driver = dynamic_step_driver.DynamicStepDriver(
        tf_env,
        collect_policy,
        observers=[replay_buffer.add_batch],
        num_steps=initial_collect_steps)
    
    # Collect Driver
    collect_driver = dynamic_step_driver.DynamicStepDriver(
        tf_env,
        collect_policy,
        observers=[replay_buffer.add_batch] + train_metrics,
        num_steps=collect_steps_per_iteration)
    
    # Checkpointers
    train_checkpointer = common.Checkpointer(
        ckpt_dir=train_dir,
        agent=tf_agent,
        global_step=global_step,
        metrics=metric_utils.MetricsGroup(train_metrics, 'train_metrics'))
    policy_checkpointer = common.Checkpointer(
        ckpt_dir=os.path.join(train_dir, 'policy'),
        policy=eval_policy,
        global_step=global_step)
    rb_checkpointer = common.Checkpointer(
        ckpt_dir=os.path.join(train_dir, 'replay_buffer'),
        max_to_keep=1,
        replay_buffer=replay_buffer)
    
    train_checkpointer.initialize_or_restore()
    policy_checkpointer.initialize_or_restore()
    rb_checkpointer.initialize_or_restore()
    
    if train_or_retrain:
        # Speed up with common.function
        if use_tf_functions:
            initial_collect_driver.run = common.function(initial_collect_driver.run)
            collect_driver.run = common.function(collect_driver.run)
            tf_agent.train = common.function(tf_agent.train)

        logging.info(
            'Initializing replay buffer by collecting experience for %d steps with '
            'a random policy.', initial_collect_steps)

        initial_collect_driver.run()

        results = metric_utils.eager_compute(
            eval_metrics,
            eval_tf_env,
            eval_policy,
            num_episodes=num_eval_episodes,
            train_step=global_step,
            summary_writer=eval_summary_writer,
            summary_prefix='Metrics',
        )
        if eval_metrics_callback is not None:
            eval_metrics_callback(results, global_step.numpy())
        metric_utils.log_metrics(eval_metrics)

        time_step = None
        policy_state = collect_policy.get_initial_state(tf_env.batch_size)

        # Variables for logging time (steps_per_sec)
        timed_at_step = global_step.numpy()
        time_acc = 0  # Time accumulation

        # Dataset generates trajetories with shape [Bx2x...]
        dataset = replay_buffer.as_dataset(
            num_parallel_calls=3,
            sample_batch_size=batch_size,
            num_steps=2,
        ).prefetch(3)
        iterator = iter(dataset)

        def train_step():
            experience, _ = next(iterator)
            return tf_agent.train(experience)

        if use_tf_functions:
            train_step = common.function(train_step)

        for _ in range(num_iterations):
            start_time = time.time()
            time_step, policy_state = collect_driver.run(
                time_step=time_step,
                policy_state=policy_state,
            )

            for _ in range(train_steps_per_iteration):
                train_loss = train_step()
            time_acc += time.time() - start_time

            if global_step.numpy() % log_interval == 0:
                logging.info('step = %d, loss = %f', global_step.numpy(),
                             train_loss.loss)
                steps_per_sec = (global_step.numpy() - timed_at_step) / time_acc
                logging.info('%.3f steps/sec', steps_per_sec)
                tf.compat.v2.summary.scalar(
                    name='global_steps_per_sec', data=steps_per_sec, step=global_step)

                # Reset time.
                timed_at_step = global_step.numpy()
                time_acc = 0

            for train_metric in train_metrics:
                train_metric.tf_summaries(
                    train_step=global_step, step_metrics=train_metrics[:2])

            if global_step.numpy() % train_checkpoint_interval == 0:
                train_checkpointer.save(global_step=global_step.numpy())
            if global_step.numpy() % policy_checkpoint_interval == 0:
                policy_checkpointer.save(global_step=global_step.numpy())
            if global_step.numpy() % rb_checkpoint_interval == 0:
                rb_checkpointer.save(global_step=global_step.numpy())

            if global_step.numpy() % eval_interval == 0:
                results = metric_utils.eager_compute(
                    eval_metrics,
                    eval_tf_env,
                    eval_policy,
                    num_episodes=num_eval_episodes,
                    train_step=global_step,
                    summary_writer=eval_summary_writer,
                    summary_prefix='Metrics',
                )
                if eval_metrics_callback is not None:
                    eval_metrics_callback(results, global_step.numpy())
                metric_utils.log_metrics(eval_metrics)

            # Record a video of current eval agent policy
            if global_step.numpy() % video_recording_interval == 0:
                filename = '{}_{}'.format(global_step.numpy(), get_timestamp())
                full_filename = os.path.join(video_dir, filename)
                create_policy_eval_video(
                    eval_policy,
                    eval_tf_env,
                    eval_py_env,
                    filename=full_filename,
                    fps=30,
                    freeze_seconds=3,
                    num_episodes=1,
                    step=global_step.numpy(),
                )
# Out:
# INFO:absl:No checkpoint available at ./data/Pendulum-v1/train
# INFO:absl:No checkpoint available at ./data/Pendulum-v1/train/policy
# INFO:absl:No checkpoint available at ./data/Pendulum-v1/train/replay_buffer
# INFO:absl:Initializing replay buffer by collecting experience for 100 steps with a random policy.
# INFO:absl:
# 		 AverageReturn = -1347.712158203125
# 		 AverageEpisodeLength = 200.0
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:383: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:383: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# INFO:absl:step = 200, loss = 0.248881
# INFO:absl:37.083 steps/sec
# INFO:absl:step = 400, loss = 0.144126
# INFO:absl:75.180 steps/sec
# INFO:absl:step = 600, loss = 0.298098
# INFO:absl:66.623 steps/sec
# INFO:absl:step = 800, loss = 1.093385
# INFO:absl:61.005 steps/sec
# INFO:absl:step = 1000, loss = 0.525363
# INFO:absl:70.155 steps/sec
# INFO:absl:
# 		 AverageReturn = -1360.58349609375
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/1000_1643997910.447711.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 1200, loss = 0.599682
# INFO:absl:69.003 steps/sec
# INFO:absl:step = 1400, loss = 0.707077
# INFO:absl:60.162 steps/sec
# INFO:absl:step = 1600, loss = 1.152277
# INFO:absl:73.140 steps/sec
# INFO:absl:step = 1800, loss = 1.260137
# INFO:absl:63.179 steps/sec
# INFO:absl:step = 2000, loss = 1.018130
# INFO:absl:65.497 steps/sec
# INFO:absl:
# 		 AverageReturn = -1145.1376953125
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/2000_1643997949.044166.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 2200, loss = 1.093548
# INFO:absl:73.229 steps/sec
# INFO:absl:step = 2400, loss = 1.095198
# INFO:absl:64.669 steps/sec
# INFO:absl:step = 2600, loss = 1.193967
# INFO:absl:69.513 steps/sec
# INFO:absl:step = 2800, loss = 1.278989
# INFO:absl:60.586 steps/sec
# INFO:absl:step = 3000, loss = 1.402886
# INFO:absl:60.706 steps/sec
# INFO:absl:
# 		 AverageReturn = -804.9655151367188
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/3000_1643997986.560991.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 3200, loss = 1.358019
# INFO:absl:79.650 steps/sec
# INFO:absl:step = 3400, loss = 1.724698
# INFO:absl:83.548 steps/sec
# INFO:absl:step = 3600, loss = 2.269277
# INFO:absl:83.388 steps/sec
# INFO:absl:step = 3800, loss = 2.458449
# INFO:absl:84.885 steps/sec
# INFO:absl:step = 4000, loss = 2.545586
# INFO:absl:87.998 steps/sec
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x7f506407e070>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x7f506407e070>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:absl:
# 		 AverageReturn = -125.23780822753906
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/4000_1643998016.292384.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 4200, loss = 2.174500
# INFO:absl:82.476 steps/sec
# INFO:absl:step = 4400, loss = 2.187369
# INFO:absl:84.578 steps/sec
# INFO:absl:step = 4600, loss = 4.360679
# INFO:absl:96.475 steps/sec
# INFO:absl:step = 4800, loss = 2.632923
# INFO:absl:100.257 steps/sec
# INFO:absl:step = 5000, loss = 3.537304
# INFO:absl:99.387 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-5000
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x7f501c0dc0d0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x7f501c0dc0d0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:absl:
# 		 AverageReturn = -193.1265106201172
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/5000_1643998044.129182.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 5200, loss = 5.218864
# INFO:absl:100.760 steps/sec
# INFO:absl:step = 5400, loss = 3.679869
# INFO:absl:102.237 steps/sec
# INFO:absl:step = 5600, loss = 4.827673
# INFO:absl:97.285 steps/sec
# INFO:absl:step = 5800, loss = 2.840884
# INFO:absl:104.152 steps/sec
# INFO:absl:step = 6000, loss = 3.158718
# INFO:absl:98.470 steps/sec
# INFO:absl:
# 		 AverageReturn = -169.31570434570312
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/6000_1643998069.031164.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 6200, loss = 4.375756
# INFO:absl:101.889 steps/sec
# INFO:absl:step = 6400, loss = 10.851881
# INFO:absl:102.673 steps/sec
# INFO:absl:step = 6600, loss = 2.968659
# INFO:absl:102.569 steps/sec
# INFO:absl:step = 6800, loss = 6.864512
# INFO:absl:100.700 steps/sec
# INFO:absl:step = 7000, loss = 3.043324
# INFO:absl:106.221 steps/sec
# INFO:absl:
# 		 AverageReturn = -374.5616455078125
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/7000_1643998093.960233.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 7200, loss = 11.046201
# INFO:absl:101.626 steps/sec
# INFO:absl:step = 7400, loss = 4.649959
# INFO:absl:102.254 steps/sec
# INFO:absl:step = 7600, loss = 7.048796
# INFO:absl:104.160 steps/sec
# INFO:absl:step = 7800, loss = 6.126988
# INFO:absl:104.297 steps/sec
# INFO:absl:step = 8000, loss = 5.781880
# INFO:absl:97.844 steps/sec
# INFO:absl:
# 		 AverageReturn = -176.71653747558594
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/8000_1643998119.20532.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 8200, loss = 4.579036
# INFO:absl:99.597 steps/sec
# INFO:absl:step = 8400, loss = 4.186569
# INFO:absl:103.846 steps/sec
# INFO:absl:step = 8600, loss = 5.638316
# INFO:absl:105.231 steps/sec
# INFO:absl:step = 8800, loss = 3.585104
# INFO:absl:105.590 steps/sec
# INFO:absl:step = 9000, loss = 5.053308
# INFO:absl:105.233 steps/sec
# INFO:absl:
# 		 AverageReturn = -223.4990692138672
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/9000_1643998143.78593.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 9200, loss = 10.165356
# INFO:absl:102.786 steps/sec
# INFO:absl:step = 9400, loss = 4.111285
# INFO:absl:104.532 steps/sec
# INFO:absl:step = 9600, loss = 10.754791
# INFO:absl:107.757 steps/sec
# INFO:absl:step = 9800, loss = 5.576198
# INFO:absl:105.852 steps/sec
# INFO:absl:step = 10000, loss = 6.760885
# INFO:absl:106.403 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-10000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-10000
# INFO:absl:
# 		 AverageReturn = -116.57991790771484
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/10000_1643998168.723841.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 10200, loss = 5.197540
# INFO:absl:97.333 steps/sec
# INFO:absl:step = 10400, loss = 4.604993
# INFO:absl:104.423 steps/sec
# INFO:absl:step = 10600, loss = 3.661000
# INFO:absl:105.126 steps/sec
# INFO:absl:step = 10800, loss = 6.021441
# INFO:absl:102.945 steps/sec
# INFO:absl:step = 11000, loss = 3.851442
# INFO:absl:106.701 steps/sec
# INFO:absl:
# 		 AverageReturn = -155.48779296875
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/11000_1643998193.695296.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 11200, loss = 5.591793
# INFO:absl:103.511 steps/sec
# INFO:absl:step = 11400, loss = 12.351226
# INFO:absl:104.470 steps/sec
# INFO:absl:step = 11600, loss = 5.122241
# INFO:absl:105.847 steps/sec
# INFO:absl:step = 11800, loss = 4.580879
# INFO:absl:107.339 steps/sec
# INFO:absl:step = 12000, loss = 5.271873
# INFO:absl:104.072 steps/sec
# INFO:absl:
# 		 AverageReturn = -139.05455017089844
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/12000_1643998218.348103.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 12200, loss = 4.931312
# INFO:absl:103.699 steps/sec
# INFO:absl:step = 12400, loss = 7.703910
# INFO:absl:106.635 steps/sec
# INFO:absl:step = 12600, loss = 3.306145
# INFO:absl:97.686 steps/sec
# INFO:absl:step = 12800, loss = 4.622779
# INFO:absl:102.752 steps/sec
# INFO:absl:step = 13000, loss = 4.596485
# INFO:absl:106.910 steps/sec
# INFO:absl:
# 		 AverageReturn = -114.0496826171875
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/13000_1643998243.289864.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 13200, loss = 4.093675
# INFO:absl:107.670 steps/sec
# INFO:absl:step = 13400, loss = 4.084113
# INFO:absl:109.534 steps/sec
# INFO:absl:step = 13600, loss = 4.589117
# INFO:absl:91.090 steps/sec
# INFO:absl:step = 13800, loss = 3.924768
# INFO:absl:98.771 steps/sec
# INFO:absl:step = 14000, loss = 1.957952
# INFO:absl:96.470 steps/sec
# INFO:absl:
# 		 AverageReturn = -125.37022399902344
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/14000_1643998268.709781.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 14200, loss = 2.601848
# INFO:absl:93.266 steps/sec
# INFO:absl:step = 14400, loss = 5.452953
# INFO:absl:85.967 steps/sec
# INFO:absl:step = 14600, loss = 4.123621
# INFO:absl:89.142 steps/sec
# INFO:absl:step = 14800, loss = 4.141356
# INFO:absl:89.806 steps/sec
# INFO:absl:step = 15000, loss = 3.549366
# INFO:absl:98.155 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-15000
# INFO:absl:
# 		 AverageReturn = -137.1083221435547
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/15000_1643998297.832708.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 15200, loss = 2.834794
# INFO:absl:77.472 steps/sec
# INFO:absl:step = 15400, loss = 2.287464
# INFO:absl:81.085 steps/sec
# INFO:absl:step = 15600, loss = 4.828629
# INFO:absl:87.322 steps/sec
# INFO:absl:step = 15800, loss = 3.859561
# INFO:absl:83.881 steps/sec
# INFO:absl:step = 16000, loss = 3.262476
# INFO:absl:84.478 steps/sec
# INFO:absl:
# 		 AverageReturn = -133.8782196044922
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/16000_1643998328.816321.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 16200, loss = 1.433035
# INFO:absl:75.418 steps/sec
# INFO:absl:step = 16400, loss = 4.441227
# INFO:absl:84.188 steps/sec
# INFO:absl:step = 16600, loss = 1.095923
# INFO:absl:77.943 steps/sec
# INFO:absl:step = 16800, loss = 1.918173
# INFO:absl:76.425 steps/sec
# INFO:absl:step = 17000, loss = 3.341074
# INFO:absl:69.534 steps/sec
# INFO:absl:
# 		 AverageReturn = -121.5958023071289
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/17000_1643998361.6225.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 17200, loss = 1.775598
# INFO:absl:78.144 steps/sec
# INFO:absl:step = 17400, loss = 1.666856
# INFO:absl:88.118 steps/sec
# INFO:absl:step = 17600, loss = 7.601252
# INFO:absl:96.829 steps/sec
# INFO:absl:step = 17800, loss = 2.194199
# INFO:absl:99.727 steps/sec
# INFO:absl:step = 18000, loss = 3.106964
# INFO:absl:74.404 steps/sec
# INFO:absl:
# 		 AverageReturn = -136.9268341064453
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/18000_1643998395.675412.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 18200, loss = 4.713746
# INFO:absl:94.631 steps/sec
# INFO:absl:step = 18400, loss = 7.270792
# INFO:absl:96.038 steps/sec
# INFO:absl:step = 18600, loss = 1.763837
# INFO:absl:96.680 steps/sec
# INFO:absl:step = 18800, loss = 3.520966
# INFO:absl:95.355 steps/sec
# INFO:absl:step = 19000, loss = 0.836312
# INFO:absl:97.678 steps/sec
# INFO:absl:
# 		 AverageReturn = -148.72561645507812
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/19000_1643998422.492249.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 19200, loss = 2.942007
# INFO:absl:98.004 steps/sec
# INFO:absl:step = 19400, loss = 2.160390
# INFO:absl:102.923 steps/sec
# INFO:absl:step = 19600, loss = 1.173789
# INFO:absl:100.334 steps/sec
# INFO:absl:step = 19800, loss = 1.188930
# INFO:absl:100.141 steps/sec
# INFO:absl:step = 20000, loss = 4.943515
# INFO:absl:100.452 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-20000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-20000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/replay_buffer/ckpt-20000
# INFO:absl:
# 		 AverageReturn = -124.0611343383789
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/20000_1643998448.607176.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 20200, loss = 6.446903
# INFO:absl:94.439 steps/sec
# INFO:absl:step = 20400, loss = 2.230104
# INFO:absl:101.030 steps/sec
# INFO:absl:step = 20600, loss = 6.673847
# INFO:absl:103.712 steps/sec
# INFO:absl:step = 20800, loss = 1.579875
# INFO:absl:100.728 steps/sec
# INFO:absl:step = 21000, loss = 2.394235
# INFO:absl:101.545 steps/sec
# INFO:absl:
# 		 AverageReturn = -218.3498992919922
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/21000_1643998474.493378.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 21200, loss = 5.714365
# INFO:absl:99.823 steps/sec
# INFO:absl:step = 21400, loss = 3.242913
# INFO:absl:102.697 steps/sec
# INFO:absl:step = 21600, loss = 0.761729
# INFO:absl:101.943 steps/sec
# INFO:absl:step = 21800, loss = 2.230280
# INFO:absl:108.167 steps/sec
# INFO:absl:step = 22000, loss = 3.466771
# INFO:absl:103.030 steps/sec
# INFO:absl:
# 		 AverageReturn = -127.01823425292969
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/22000_1643998499.78565.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 22200, loss = 2.774669
# INFO:absl:107.394 steps/sec
# INFO:absl:step = 22400, loss = 0.977959
# INFO:absl:113.432 steps/sec
# INFO:absl:step = 22600, loss = 2.867495
# INFO:absl:109.179 steps/sec
# INFO:absl:step = 22800, loss = 1.884859
# INFO:absl:107.340 steps/sec
# INFO:absl:step = 23000, loss = 1.211145
# INFO:absl:112.081 steps/sec
# INFO:absl:
# 		 AverageReturn = -127.0050048828125
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/23000_1643998523.409131.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 23200, loss = 4.096415
# INFO:absl:104.861 steps/sec
# INFO:absl:step = 23400, loss = 1.336639
# INFO:absl:104.230 steps/sec
# INFO:absl:step = 23600, loss = 3.783466
# INFO:absl:103.008 steps/sec
# INFO:absl:step = 23800, loss = 2.109385
# INFO:absl:106.831 steps/sec
# INFO:absl:step = 24000, loss = 2.507508
# INFO:absl:106.436 steps/sec
# INFO:absl:
# 		 AverageReturn = -143.80191040039062
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/24000_1643998547.984043.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 24200, loss = 2.213600
# INFO:absl:106.082 steps/sec
# INFO:absl:step = 24400, loss = 2.014045
# INFO:absl:106.629 steps/sec
# INFO:absl:step = 24600, loss = 1.722977
# INFO:absl:109.901 steps/sec
# INFO:absl:step = 24800, loss = 3.209049
# INFO:absl:104.272 steps/sec
# INFO:absl:step = 25000, loss = 3.723192
# INFO:absl:104.122 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-25000
# INFO:absl:
# 		 AverageReturn = -150.00927734375
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/25000_1643998572.241537.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 25200, loss = 4.292269
# INFO:absl:108.400 steps/sec
# INFO:absl:step = 25400, loss = 1.356083
# INFO:absl:111.552 steps/sec
# INFO:absl:step = 25600, loss = 3.156459
# INFO:absl:111.017 steps/sec
# INFO:absl:step = 25800, loss = 2.383399
# INFO:absl:116.708 steps/sec
# INFO:absl:step = 26000, loss = 2.857122
# INFO:absl:114.948 steps/sec
# INFO:absl:
# 		 AverageReturn = -129.8372802734375
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/26000_1643998595.666858.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 26200, loss = 2.055635
# INFO:absl:106.872 steps/sec
# INFO:absl:step = 26400, loss = 2.796139
# INFO:absl:104.877 steps/sec
# INFO:absl:step = 26600, loss = 2.729438
# INFO:absl:100.490 steps/sec
# INFO:absl:step = 26800, loss = 2.302783
# INFO:absl:105.907 steps/sec
# INFO:absl:step = 27000, loss = 3.227871
# INFO:absl:111.864 steps/sec
# INFO:absl:
# 		 AverageReturn = -136.13540649414062
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/27000_1643998620.166746.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 27200, loss = 3.005331
# INFO:absl:98.507 steps/sec
# INFO:absl:step = 27400, loss = 2.526625
# INFO:absl:82.312 steps/sec
# INFO:absl:step = 27600, loss = 2.244994
# INFO:absl:78.020 steps/sec
# INFO:absl:step = 27800, loss = 2.208565
# INFO:absl:63.359 steps/sec
# INFO:absl:step = 28000, loss = 2.847730
# INFO:absl:66.184 steps/sec
# INFO:absl:
# 		 AverageReturn = -160.9571075439453
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/28000_1643998651.745649.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 28200, loss = 3.962474
# INFO:absl:63.841 steps/sec
# INFO:absl:step = 28400, loss = 2.584571
# INFO:absl:69.135 steps/sec
# INFO:absl:step = 28600, loss = 1.522332
# INFO:absl:84.781 steps/sec
# INFO:absl:step = 28800, loss = 3.614547
# INFO:absl:87.571 steps/sec
# INFO:absl:step = 29000, loss = 5.505716
# INFO:absl:88.807 steps/sec
# INFO:absl:
# 		 AverageReturn = -158.9287109375
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/29000_1643998684.396964.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 29200, loss = 2.551297
# INFO:absl:77.178 steps/sec
# INFO:absl:step = 29400, loss = 4.416175
# INFO:absl:62.634 steps/sec
# INFO:absl:step = 29600, loss = 1.475764
# INFO:absl:67.765 steps/sec
# INFO:absl:step = 29800, loss = 3.081162
# INFO:absl:69.964 steps/sec
# INFO:absl:step = 30000, loss = 2.605061
# INFO:absl:58.504 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-30000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-30000
# INFO:absl:
# 		 AverageReturn = -227.7852020263672
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/30000_1643998720.625425.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 30200, loss = 1.887408
# INFO:absl:68.973 steps/sec
# INFO:absl:step = 30400, loss = 0.882515
# INFO:absl:72.420 steps/sec
# INFO:absl:step = 30600, loss = 1.256151
# INFO:absl:66.080 steps/sec
# INFO:absl:step = 30800, loss = 3.429702
# INFO:absl:71.121 steps/sec
# INFO:absl:step = 31000, loss = 0.824358
# INFO:absl:83.469 steps/sec
# INFO:absl:
# 		 AverageReturn = -219.8830108642578
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/31000_1643998756.253933.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 31200, loss = 2.274310
# INFO:absl:96.727 steps/sec
# INFO:absl:step = 31400, loss = 1.626891
# INFO:absl:101.751 steps/sec
# INFO:absl:step = 31600, loss = 3.878265
# INFO:absl:102.074 steps/sec
# INFO:absl:step = 31800, loss = 1.111642
# INFO:absl:104.948 steps/sec
# INFO:absl:step = 32000, loss = 6.271587
# INFO:absl:100.976 steps/sec
# INFO:absl:
# 		 AverageReturn = -155.30233764648438
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/32000_1643998781.46752.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 32200, loss = 3.354375
# INFO:absl:96.883 steps/sec
# INFO:absl:step = 32400, loss = 3.556875
# INFO:absl:104.959 steps/sec
# INFO:absl:step = 32600, loss = 2.389284
# INFO:absl:101.224 steps/sec
# INFO:absl:step = 32800, loss = 5.597456
# INFO:absl:105.899 steps/sec
# INFO:absl:step = 33000, loss = 5.800630
# INFO:absl:101.616 steps/sec
# INFO:absl:
# 		 AverageReturn = -181.29867553710938
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/33000_1643998806.68924.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 33200, loss = 1.059579
# INFO:absl:99.292 steps/sec
# INFO:absl:step = 33400, loss = 2.437199
# INFO:absl:98.355 steps/sec
# INFO:absl:step = 33600, loss = 3.739871
# INFO:absl:105.687 steps/sec
# INFO:absl:step = 33800, loss = 4.373796
# INFO:absl:103.825 steps/sec
# INFO:absl:step = 34000, loss = 5.552338
# INFO:absl:100.267 steps/sec
# INFO:absl:
# 		 AverageReturn = -171.2118682861328
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/34000_1643998831.929791.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 34200, loss = 5.583385
# INFO:absl:92.345 steps/sec
# INFO:absl:step = 34400, loss = 1.948341
# INFO:absl:103.865 steps/sec
# INFO:absl:step = 34600, loss = 8.825289
# INFO:absl:99.807 steps/sec
# INFO:absl:step = 34800, loss = 4.342056
# INFO:absl:104.022 steps/sec
# INFO:absl:step = 35000, loss = 2.477560
# INFO:absl:105.214 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-35000
# INFO:absl:
# 		 AverageReturn = -156.86923217773438
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/35000_1643998857.610768.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 35200, loss = 3.640491
# INFO:absl:101.503 steps/sec
# INFO:absl:step = 35400, loss = 1.231930
# INFO:absl:103.949 steps/sec
# INFO:absl:step = 35600, loss = 3.818922
# INFO:absl:88.694 steps/sec
# INFO:absl:step = 35800, loss = 6.618157
# INFO:absl:104.655 steps/sec
# INFO:absl:step = 36000, loss = 6.330909
# INFO:absl:102.369 steps/sec
# INFO:absl:
# 		 AverageReturn = -168.59567260742188
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/36000_1643998882.996565.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 36200, loss = 8.791430
# INFO:absl:105.431 steps/sec
# INFO:absl:step = 36400, loss = 3.748121
# INFO:absl:103.978 steps/sec
# INFO:absl:step = 36600, loss = 3.254324
# INFO:absl:107.591 steps/sec
# INFO:absl:step = 36800, loss = 6.999625
# INFO:absl:95.925 steps/sec
# INFO:absl:step = 37000, loss = 0.868245
# INFO:absl:105.024 steps/sec
# INFO:absl:
# 		 AverageReturn = -138.29849243164062
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/37000_1643998908.001554.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 37200, loss = 1.722868
# INFO:absl:102.261 steps/sec
# INFO:absl:step = 37400, loss = 6.653257
# INFO:absl:104.735 steps/sec
# INFO:absl:step = 37600, loss = 2.832798
# INFO:absl:106.338 steps/sec
# INFO:absl:step = 37800, loss = 3.009333
# INFO:absl:104.900 steps/sec
# INFO:absl:step = 38000, loss = 2.291460
# INFO:absl:106.112 steps/sec
# INFO:absl:
# 		 AverageReturn = -187.11618041992188
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/38000_1643998933.002413.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 38200, loss = 1.186573
# INFO:absl:107.930 steps/sec
# INFO:absl:step = 38400, loss = 0.839092
# INFO:absl:106.130 steps/sec
# INFO:absl:step = 38600, loss = 2.988325
# INFO:absl:105.592 steps/sec
# INFO:absl:step = 38800, loss = 2.375613
# INFO:absl:106.334 steps/sec
# INFO:absl:step = 39000, loss = 0.778822
# INFO:absl:107.826 steps/sec
# INFO:absl:
# 		 AverageReturn = -160.52310180664062
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/39000_1643998957.47187.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 39200, loss = 1.439700
# INFO:absl:106.115 steps/sec
# INFO:absl:step = 39400, loss = 3.825422
# INFO:absl:105.664 steps/sec
# INFO:absl:step = 39600, loss = 6.491390
# INFO:absl:110.386 steps/sec
# INFO:absl:step = 39800, loss = 2.665693
# INFO:absl:106.007 steps/sec
# INFO:absl:step = 40000, loss = 0.387650
# INFO:absl:107.119 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-40000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-40000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/replay_buffer/ckpt-40000
# INFO:absl:
# 		 AverageReturn = -209.4106903076172
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/40000_1643998982.733173.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 40200, loss = 3.613610
# INFO:absl:99.057 steps/sec
# INFO:absl:step = 40400, loss = 1.396981
# INFO:absl:104.886 steps/sec
# INFO:absl:step = 40600, loss = 2.404204
# INFO:absl:104.151 steps/sec
# INFO:absl:step = 40800, loss = 0.900306
# INFO:absl:101.701 steps/sec
# INFO:absl:step = 41000, loss = 2.957471
# INFO:absl:109.573 steps/sec
# INFO:absl:
# 		 AverageReturn = -148.14247131347656
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/41000_1643999007.847805.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 41200, loss = 1.793544
# INFO:absl:106.401 steps/sec
# INFO:absl:step = 41400, loss = 2.476681
# INFO:absl:106.761 steps/sec
# INFO:absl:step = 41600, loss = 3.540230
# INFO:absl:98.686 steps/sec
# INFO:absl:step = 41800, loss = 4.441093
# INFO:absl:108.325 steps/sec
# INFO:absl:step = 42000, loss = 2.773392
# INFO:absl:105.302 steps/sec
# INFO:absl:
# 		 AverageReturn = -109.89106750488281
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/42000_1643999032.43763.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 42200, loss = 4.659610
# INFO:absl:105.408 steps/sec
# INFO:absl:step = 42400, loss = 3.076111
# INFO:absl:105.154 steps/sec
# INFO:absl:step = 42600, loss = 3.063439
# INFO:absl:101.687 steps/sec
# INFO:absl:step = 42800, loss = 2.696337
# INFO:absl:96.425 steps/sec
# INFO:absl:step = 43000, loss = 1.564673
# INFO:absl:107.548 steps/sec
# INFO:absl:
# 		 AverageReturn = -136.23448181152344
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/43000_1643999057.331406.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 43200, loss = 3.458982
# INFO:absl:106.318 steps/sec
# INFO:absl:step = 43400, loss = 2.314910
# INFO:absl:105.720 steps/sec
# INFO:absl:step = 43600, loss = 6.925186
# INFO:absl:108.574 steps/sec
# INFO:absl:step = 43800, loss = 2.045494
# INFO:absl:100.077 steps/sec
# INFO:absl:step = 44000, loss = 1.082078
# INFO:absl:103.270 steps/sec
# INFO:absl:
# 		 AverageReturn = -181.28158569335938
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/44000_1643999082.263381.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 44200, loss = 5.416776
# INFO:absl:106.651 steps/sec
# INFO:absl:step = 44400, loss = 4.103491
# INFO:absl:107.202 steps/sec
# INFO:absl:step = 44600, loss = 8.069951
# INFO:absl:105.926 steps/sec
# INFO:absl:step = 44800, loss = 7.015952
# INFO:absl:104.413 steps/sec
# INFO:absl:step = 45000, loss = 2.840520
# INFO:absl:104.241 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-45000
# INFO:absl:
# 		 AverageReturn = -181.0987091064453
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/45000_1643999107.402603.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 45200, loss = 5.394607
# INFO:absl:104.366 steps/sec
# INFO:absl:step = 45400, loss = 1.159198
# INFO:absl:101.421 steps/sec
# INFO:absl:step = 45600, loss = 1.721123
# INFO:absl:108.609 steps/sec
# INFO:absl:step = 45800, loss = 4.626910
# INFO:absl:107.787 steps/sec
# INFO:absl:step = 46000, loss = 3.606389
# INFO:absl:107.732 steps/sec
# INFO:absl:
# 		 AverageReturn = -172.862060546875
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/46000_1643999132.170038.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 46200, loss = 5.749370
# INFO:absl:96.658 steps/sec
# INFO:absl:step = 46400, loss = 5.086937
# INFO:absl:90.478 steps/sec
# INFO:absl:step = 46600, loss = 2.213749
# INFO:absl:101.852 steps/sec
# INFO:absl:step = 46800, loss = 3.401913
# INFO:absl:104.825 steps/sec
# INFO:absl:step = 47000, loss = 3.001341
# INFO:absl:109.662 steps/sec
# INFO:absl:
# 		 AverageReturn = -180.51348876953125
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/47000_1643999157.582336.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 47200, loss = 11.488702
# INFO:absl:103.926 steps/sec
# INFO:absl:step = 47400, loss = 1.264485
# INFO:absl:105.512 steps/sec
# INFO:absl:step = 47600, loss = 2.446428
# INFO:absl:97.361 steps/sec
# INFO:absl:step = 47800, loss = 8.860289
# ...
# INFO:absl:All done
# INFO:absl:step = 83200, loss = 3.495766
# INFO:absl:104.677 steps/sec
# INFO:absl:step = 83400, loss = 1.096772
# INFO:absl:98.154 steps/sec
# INFO:absl:step = 83600, loss = 0.987027
# INFO:absl:105.877 steps/sec
# INFO:absl:step = 83800, loss = 3.738997
# INFO:absl:106.468 steps/sec
# INFO:absl:step = 84000, loss = 6.439313
# INFO:absl:105.520 steps/sec
# INFO:absl:
# 		 AverageReturn = -157.8317108154297
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/84000_1644000083.923983.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 84200, loss = 11.577784
# INFO:absl:107.006 steps/sec
# INFO:absl:step = 84400, loss = 3.746855
# INFO:absl:105.105 steps/sec
# INFO:absl:step = 84600, loss = 9.278867
# INFO:absl:108.087 steps/sec
# INFO:absl:step = 84800, loss = 2.241743
# INFO:absl:101.679 steps/sec
# INFO:absl:step = 85000, loss = 2.511809
# INFO:absl:104.996 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-85000
# INFO:absl:
# 		 AverageReturn = -142.15943908691406
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/85000_1644000108.75474.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 85200, loss = 13.334500
# INFO:absl:105.678 steps/sec
# INFO:absl:step = 85400, loss = 1.768206
# INFO:absl:106.973 steps/sec
# INFO:absl:step = 85600, loss = 15.416212
# INFO:absl:105.745 steps/sec
# INFO:absl:step = 85800, loss = 3.365734
# INFO:absl:108.501 steps/sec
# INFO:absl:step = 86000, loss = 2.368815
# INFO:absl:106.370 steps/sec
# INFO:absl:
# 		 AverageReturn = -153.7881622314453
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/86000_1644000133.346225.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 86200, loss = 3.323181
# INFO:absl:108.693 steps/sec
# INFO:absl:step = 86400, loss = 4.699564
# INFO:absl:106.624 steps/sec
# INFO:absl:step = 86600, loss = 0.546732
# INFO:absl:107.754 steps/sec
# INFO:absl:step = 86800, loss = 4.809723
# INFO:absl:108.018 steps/sec
# INFO:absl:step = 87000, loss = 7.645535
# INFO:absl:107.323 steps/sec
# INFO:absl:
# 		 AverageReturn = -133.6667938232422
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/87000_1644000157.723173.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 87200, loss = 5.195250
# INFO:absl:105.589 steps/sec
# INFO:absl:step = 87400, loss = 0.568697
# INFO:absl:101.991 steps/sec
# INFO:absl:step = 87600, loss = 3.670221
# INFO:absl:106.959 steps/sec
# INFO:absl:step = 87800, loss = 0.711478
# INFO:absl:102.403 steps/sec
# INFO:absl:step = 88000, loss = 3.104993
# INFO:absl:104.860 steps/sec
# INFO:absl:
# 		 AverageReturn = -156.31680297851562
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/88000_1644000182.552775.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 88200, loss = 2.690660
# INFO:absl:98.248 steps/sec
# INFO:absl:step = 88400, loss = 4.899457
# INFO:absl:106.070 steps/sec
# INFO:absl:step = 88600, loss = 2.999949
# INFO:absl:103.541 steps/sec
# INFO:absl:step = 88800, loss = 9.693905
# INFO:absl:108.834 steps/sec
# INFO:absl:step = 89000, loss = 0.293717
# INFO:absl:104.253 steps/sec
# INFO:absl:
# 		 AverageReturn = -180.16995239257812
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/89000_1644000207.495235.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 89200, loss = 1.478433
# INFO:absl:106.435 steps/sec
# INFO:absl:step = 89400, loss = 1.018484
# INFO:absl:102.558 steps/sec
# INFO:absl:step = 89600, loss = 4.420493
# INFO:absl:97.744 steps/sec
# INFO:absl:step = 89800, loss = 2.745467
# INFO:absl:103.530 steps/sec
# INFO:absl:step = 90000, loss = 2.353446
# INFO:absl:104.635 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-90000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-90000
# INFO:absl:
# 		 AverageReturn = -180.29063415527344
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/90000_1644000232.90811.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 90200, loss = 0.967596
# INFO:absl:107.155 steps/sec
# INFO:absl:step = 90400, loss = 4.425800
# INFO:absl:106.568 steps/sec
# INFO:absl:step = 90600, loss = 13.032131
# INFO:absl:99.268 steps/sec
# INFO:absl:step = 90800, loss = 4.381842
# INFO:absl:92.324 steps/sec
# INFO:absl:step = 91000, loss = 4.457462
# INFO:absl:104.753 steps/sec
# INFO:absl:
# 		 AverageReturn = -119.76435852050781
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/91000_1644000258.078229.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 91200, loss = 1.809623
# INFO:absl:101.788 steps/sec
# INFO:absl:step = 91400, loss = 6.996783
# INFO:absl:106.969 steps/sec
# INFO:absl:step = 91600, loss = 13.429641
# INFO:absl:106.621 steps/sec
# INFO:absl:step = 91800, loss = 2.409302
# INFO:absl:105.738 steps/sec
# INFO:absl:step = 92000, loss = 1.849934
# INFO:absl:107.060 steps/sec
# INFO:absl:
# 		 AverageReturn = -144.02536010742188
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/92000_1644000282.531831.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 92200, loss = 0.377256
# INFO:absl:102.645 steps/sec
# INFO:absl:step = 92400, loss = 0.172497
# INFO:absl:106.072 steps/sec
# INFO:absl:step = 92600, loss = 3.800016
# INFO:absl:107.732 steps/sec
# INFO:absl:step = 92800, loss = 13.003379
# INFO:absl:105.269 steps/sec
# INFO:absl:step = 93000, loss = 12.412816
# INFO:absl:107.077 steps/sec
# INFO:absl:
# 		 AverageReturn = -176.75990295410156
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/93000_1644000307.451481.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 93200, loss = 8.678003
# INFO:absl:107.966 steps/sec
# INFO:absl:step = 93400, loss = 7.060693
# INFO:absl:106.739 steps/sec
# INFO:absl:step = 93600, loss = 11.947394
# INFO:absl:103.767 steps/sec
# INFO:absl:step = 93800, loss = 6.564399
# INFO:absl:109.048 steps/sec
# INFO:absl:step = 94000, loss = 36.369576
# INFO:absl:107.226 steps/sec
# INFO:absl:
# 		 AverageReturn = -162.28797912597656
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/94000_1644000332.118394.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 94200, loss = 3.830304
# INFO:absl:95.886 steps/sec
# INFO:absl:step = 94400, loss = 2.291348
# INFO:absl:105.605 steps/sec
# INFO:absl:step = 94600, loss = 3.053708
# INFO:absl:108.067 steps/sec
# INFO:absl:step = 94800, loss = 0.455340
# INFO:absl:105.459 steps/sec
# INFO:absl:step = 95000, loss = 0.844327
# INFO:absl:99.113 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-95000
# INFO:absl:
# 		 AverageReturn = -138.64195251464844
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/95000_1644000357.54389.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 95200, loss = 1.393556
# INFO:absl:105.828 steps/sec
# INFO:absl:step = 95400, loss = 0.703176
# INFO:absl:96.636 steps/sec
# INFO:absl:step = 95600, loss = 2.178610
# INFO:absl:96.131 steps/sec
# INFO:absl:step = 95800, loss = 2.898498
# INFO:absl:104.616 steps/sec
# INFO:absl:step = 96000, loss = 1.582280
# INFO:absl:103.413 steps/sec
# INFO:absl:
# 		 AverageReturn = -146.3063201904297
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/96000_1644000382.526005.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 96200, loss = 2.168628
# INFO:absl:103.223 steps/sec
# INFO:absl:step = 96400, loss = 6.253129
# INFO:absl:104.996 steps/sec
# INFO:absl:step = 96600, loss = 1.749232
# INFO:absl:105.001 steps/sec
# INFO:absl:step = 96800, loss = 2.630203
# INFO:absl:105.400 steps/sec
# INFO:absl:step = 97000, loss = 0.957340
# INFO:absl:94.687 steps/sec
# INFO:absl:
# 		 AverageReturn = -145.87539672851562
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/97000_1644000407.328662.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 97200, loss = 3.254169
# INFO:absl:102.892 steps/sec
# INFO:absl:step = 97400, loss = 12.740598
# INFO:absl:104.653 steps/sec
# INFO:absl:step = 97600, loss = 5.853394
# INFO:absl:99.898 steps/sec
# INFO:absl:step = 97800, loss = 2.199114
# INFO:absl:106.863 steps/sec
# INFO:absl:step = 98000, loss = 3.744402
# INFO:absl:104.926 steps/sec
# INFO:absl:
# 		 AverageReturn = -98.67169189453125
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/98000_1644000432.082336.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 98200, loss = 21.521559
# INFO:absl:107.123 steps/sec
# INFO:absl:step = 98400, loss = 1.753860
# INFO:absl:106.475 steps/sec
# INFO:absl:step = 98600, loss = 2.087037
# INFO:absl:105.280 steps/sec
# INFO:absl:step = 98800, loss = 3.964882
# INFO:absl:106.631 steps/sec
# INFO:absl:step = 99000, loss = 0.897916
# INFO:absl:107.281 steps/sec
# INFO:absl:
# 		 AverageReturn = -125.27018737792969
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/99000_1644000456.792707.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done
# INFO:absl:step = 99200, loss = 3.254452
# INFO:absl:105.511 steps/sec
# INFO:absl:step = 99400, loss = 3.188568
# INFO:absl:105.057 steps/sec
# INFO:absl:step = 99600, loss = 4.195211
# INFO:absl:104.635 steps/sec
# INFO:absl:step = 99800, loss = 1.879910
# INFO:absl:108.233 steps/sec
# INFO:absl:step = 100000, loss = 30.845720
# INFO:absl:105.639 steps/sec
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/ckpt-100000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/policy/ckpt-100000
# INFO:absl:Saved checkpoint: ./data/Pendulum-v1/train/replay_buffer/ckpt-100000
# INFO:absl:
# 		 AverageReturn = -158.65000915527344
# 		 AverageEpisodeLength = 200.0
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: ./data/Pendulum-v1/video/100000_1644000482.768485.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done

# %%
time_step = eval_py_env.reset()

# %%
saved_filename = create_policy_eval_video(tf_agent.policy, eval_tf_env, eval_py_env, fps=15, freeze_seconds=3, num_episodes=1)
# Out:
# INFO:absl:Env: Pendulum-v1
# INFO:absl:Filename: 1643997780.938523.mp4
# INFO:absl:Begin #1 of 1
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# INFO:absl:All done

# %%
embed_mp4(saved_filename)
